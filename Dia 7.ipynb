# %% [markdown]
# #  Día 7: Proyecto aplicado (Finanzas)
#
# ## 1. Bienvenida al Día 7
#
# Hoy llegamos al último día del módulo 1. Felicitaciones por todo lo que aprendieron y practicaron hasta acá. Ya tienen herramientas muy importantes en sus manos: saben trabajar con Python, usar Jupyter, manipular datos con Pandas y hacer cálculos que resumen información. Todo eso que aprendieron, hoy lo van a poner en práctica con un proyecto realista.
#
#  *Objetivo de este bloque*: dar un cierre motivador y reconocer el esfuerzo de los alumnos.
#
# ---
#
# ## 2. Introducción al proyecto
#
# En el mundo laboral, la mayoría de las veces no trabajamos con ejemplos inventados, sino con datos reales de empresas, bancos o instituciones. Hoy vamos a simular una situación de análisis financiero: vamos a trabajar con un **dataset de préstamos**.
#
#  *Objetivo*: mostrar que el proyecto refleja una tarea real del día a día en empresas.
#
# ---
#
# ## 3. Explicar de qué trata el proyecto
#
# Imaginemos que ustedes trabajan en el área de análisis de riesgos de un banco o una financiera. Reciben un archivo con la información de préstamos: montos, fechas, estado de mora. La tarea es analizar esos datos para entender:
#
# * cuál es el monto promedio de los préstamos,
# * qué porcentaje de clientes caen en mora,
# * cuánto tarda en recuperarse un préstamo en mora.
#
#  *Objetivo*: poner al alumno en el rol de un analista real.
#
# ---
#
# ## 4. Explicar que deben aplicar lo aprendido
#
# Todo lo que tienen que usar para resolver este proyecto ya lo vieron en el módulo:
#
# * Cómo abrir archivos Excel/CSV en Pandas.
# * Cómo limpiar datos básicos (renombrar columnas, tratar valores vacíos).
# * Cómo crear columnas nuevas a partir de cálculos.
# * Cómo agrupar datos y calcular métricas con `groupby` y `agg`.
# * Cómo mostrar resultados finales en tablas claras.
#
#  *Objetivo*: remarcar que no necesitan nada nuevo, solo consolidar lo que ya saben.
#
# ---
#
# ## 5. Desarrollo del proyecto – Instrucciones
#
# ### 📌 Presentación del trabajo
#
# El proyecto se centra en analizar un **dataset de préstamos** y obtener conclusiones útiles para un área financiera.
#
# ###  Objetivo
#
# El objetivo es aplicar todas las técnicas del módulo 1 para convertir datos crudos en información útil. Van a demostrar que pueden limpiar, transformar y resumir datos con claridad.
#
# ###  ¿Por qué hacemos este proyecto?
#
# Porque en la vida laboral un analista de datos no se mide por cuántos ejercicios de práctica resolvió, sino por su capacidad de agarrar un dataset nuevo y convertirlo en información para tomar decisiones.
#
# ###  Qué van a aprender
#
# * Cómo organizar un flujo de trabajo de principio a fin (leer, limpiar, analizar, presentar).
# * Cómo conectar lo aprendido en los 6 días anteriores.
# * Cómo comunicar resultados claros a partir de datos.
#
# ###  Reglas obligatorias
#
# * Usar solo herramientas vistas en el módulo (Python, Jupyter, Pandas, NumPy básico).
# * La limpieza debe incluir: eliminar o marcar valores vacíos, estandarizar nombres de columnas.
# * Los cálculos deben hacerse con `groupby`, `agg`, `.mean()`, `.sum()`, `.count()` según corresponda.
# * El resultado final debe estar en **una tabla clara**, presentada en el notebook.
#
# ### ✅ Resultado esperado
#
# Un notebook que muestre:
#
# 1. El dataset cargado correctamente.
# 2. Limpieza básica aplicada.
# 3. Métricas calculadas:
#
#    * monto promedio de los préstamos,
#    * porcentaje de mora,
#    * tiempo promedio de recuperación.
# 4. Una tabla final con esas métricas.
# 5. Una conclusión corta escrita en una celda Markdown: qué significa este resultado.
#
# ---
